# %%
import audiomate
import IPython.display as ipd

# %%
path = 'data/download/swc'
ds = audiomate.Corpus.load(path, reader='swc')

# %%
path = 'data/download/common_voice'
ds = audiomate.Corpus.load(path, reader='common-voice')

# %%
utt = ds.utterances['common_voice_de_17737392']
transcript = utt.label_lists[audiomate.corpus.LL_WORD_TRANSCRIPT].join()
samples = utt.read_samples(sr=16000)

print(transcript)
ipd.Audio(samples, rate=16000)
# Out:
# finanzielle Unabhängigkeit
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
